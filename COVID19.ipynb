# %%
# Importando bibliotecas nescessárias:

from PIL import Image
from os import listdir
from os.path import isdir
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG19
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers

# %%
# Carregando uma imagem:

def select_image(filename):
    
    image = Image,open(filename)
    
    image = image.convert('RGB')
    image = image.resize((150,150))
    
    return np.asarray(image)

# %%
# Carregando uma classse:

def load_Class(diretorio, classe, imagens, labels):
    # Iterando arquivos
    
    for filename in listdir(diretorio):
        
        path = diretorio + filename
        
        try:
            imagens.append(select_image(path))
            labels.append(classe)
        except:
            print("Erro ao ler imagem {}".format(path))

# %%
# Selecionado o Dataset:

def select_data_set(diretorio):
    
    imagens = list()
    labels = list()
    
    for subdir in listdir(diretorio):
        # path
        path = diretorio + subdir + '//'
        
        if not isdir(path):
            continue
        imagens, labels = load_Class(path, subdir, imagens, labels)
        
    return imagens, labels

# %%
# Carregando o dataset COVID-19:

covid_dataset = "C:\dataset\covid-carlos\images"
imagens, labels = select_data_set(covid_dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b97057174339> in <module>()
#       2
#       3 covid_dataset = "C:\dataset\covid-carlos\images"
# ----> 4 imagens, labels = select_data_set(covid_dataset)
#
# <ipython-input-4-cbd3f53661bd> in select_data_set(diretorio)
#       6     labels = list()
#       7
# ----> 8     for subdir in listdir(diretorio):
#       9         # path
#      10         path = diretorio + subdir + '//'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\dataset\\covid-carlos\\images'

# %%
imagens

# %%
#Normalizando as imagens:

imagens = np.array(imagens) / 255.0 
labels = np.array(labels)

# %%
# Tratando classes - Labels:

lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels[0]

labels = to_categorical(labels)
labels[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a0119da95375> in <module>
#       2
#       3 lb = LabelBinarizer()
# ----> 4 labels = lb.fit_transform(labels)
#       5 labels[0]
#       6
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     437             Shape will be [n_samples, 1] for binary problems.
#     438         """
# --> 439         return self.fit(y).transform(y)
#     440
#     441     def transform(self, y):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/preprocessing/label.py in fit(self, y)
#     411                              "label binarization")
#     412         if _num_samples(y) == 0:
# --> 413             raise ValueError('y has 0 samples: %r' % y)
#     414
#     415         self.sparse_input_ = sp.issparse(y)
#
# ValueError: y has 0 samples: array([], dtype=float64)

# %%
# Definindo hyperparemetros:

batch_size = 32 
input_shape = (150, 150, 3) 
radom_state = 42 
alpha = 1e-5  
epoch = 100

# %%
# O que são callbacks:

from tensorflow.kerascallbacks import ModelCheckpoint, ReduceLROnPlateu

# %%
# usamos um arquivo para salvar:

filepath="transferlearning_weights.hdf5"
chepoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max_val_acc')

# %%
ir_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, min_delta=alpha, patience5, verbose=1)

# %%
# Array de calbacks:

callbacks = [checkpoint, lr_reduce]

# %%
# Particionando dataset em teste e treino:

(trainX, testeX, trainY, testY) = train_test_split(imagens, labels, teste_size=0.2, stratify=labels, radom_state=radom_state)

# %%
train_datagen = ImageDataGenerator(rotation_range=20, zoom_range=0.2)

train_datagen.fit(trainX) 

data_aug = train_datagen.flow(trainX, trainY, batch_size=batch_size)

# %%
# Transfer Learning:

conv_base = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)

# %%
conv_base.summary()

# %%
#vou dizer que a rede é toda treinavel:

conv_base.treinable = True
set_trainable = False // falso

for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False

# %%
conv_base.sumary()

# %%
# Criando o modelo com o VGG19 como base:

model = models.Sequencial()
model.add(conv_base) 
model.add(layers.GlobalAveragePooling2D()) 
model.add(layers.BatchNormalization()) 
model.add(layers.Flatten()) 
model.add(layers.Dense(128, activation='relu')) 
model.add(layers.Droupout(0.6)) 
model.add(layers.Dense(2, activation='softmax'))

# %%
model.summary()

# %%
# Compilando o meu modelo:

model.compile(loss='binary_crossentropy', 
              optimizer='adam',
              metrics=['acc'])

# %%
# Treinando o modelo - OBS: "Não faça isso agora, esse passo deve ser feito antes da apresetação:"
history = model.fit_generator(data_aug, 
                               steps_per_epoch=len(train) // batch_size,
                               validation_dat=(testX, testY),
                               validation_steps=len(testX) // batch_size,
                               callbacks=callbacks,
                               epochs=epoch)

# %%
# Analisando os dados :

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
pltylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss:

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train, 'test'], loc='upper left'])
plt.show()

# %%
# Gerando matriz de confusão:

from sklearn.metrics import confusion_matrix
pred = model.predict(testX)
pred = np.argmax(testY,axis =1)

# %%
cm = confusion_matrix(y_true, pred)
total = sum(sum(cm))
acc = (cm[0,0] + cm[1, 1] / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
       
print("Acurácia: {:.4f}".format(acc))
print("Sensitividade: {:.4f".format(sensitivity))
print("Especificidade: {:.4f}".format(specificity))
